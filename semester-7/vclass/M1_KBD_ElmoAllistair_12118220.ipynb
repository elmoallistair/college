# %% [markdown]
# ### Elmo Allistair – 12118220 – 4KA17
#
# <hr>
#
# ### Jawaban

# %%
compactness_mean = data.compactness_mean
concavity_mean = data.concavity_mean

# %% [markdown]
# ### Korelasi `compactness_mean` dengan `concavity_mean`

# %%
p = sns.jointplot(compactness_mean, concavity_mean, kind="reg")
p.fig.suptitle("Korelasi compactness_mean dengan concavity_mean");
p.fig.subplots_adjust(top=0.9)

# %% [markdown]
# Berdasarkan diagram yang dihasilkan, dapat disimpukan `compactness_mean` dan `concavity_mean` memiliki korelasi positif kuat.

# %% [markdown]
# ### Covariance dari `compactness_mean` dengan `concavity_mean`.

# %%
compactness_mean.cov(concavity_mean)
# Out:
# 0.00371813492178018

# %% [markdown]
# Nilai Covariance dari `compactness_mean` dengan `concavity_mean` adalah 0.00371.\
# Nilai Covariace positif menunjukkan hubungan dua variabel yang positif.

# %% [markdown]
# ### Pearson Correlation dari `compactness_mean` dengan `concavity_mean`.

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(compactness_mean, concavity_mean)
corr
# Out:
# 0.8831206701772509

# %% [markdown]
# Nilai Pearson Correlation dari `compactness_mean` dengan `concavity_mean` adalah 0.88312.\
# Artinya, keduanya memiliki hubungan keeratan linier yang kuat.

# %% [markdown]
# ### Uji Hipotesis dari `compactness_mean` dengan `concavity_mean`.

# %%
statistic, p_value = stats.ttest_rel(compactness_mean, concavity_mean)
p_value
# Out:
# 4.29231315918515e-18

# %% [markdown]
# Nilai Probabilitas `p-value` dari `compactness_mean` dengan `concavity_mean` adalah `4.29231315918515e-18`.\
# Karena nilai `p-value` lebih kecil dari `0,05`, maka dapat menyimpulkan bahwa ada korelasi yang signifikan secara statistik antara kedua variabel.
